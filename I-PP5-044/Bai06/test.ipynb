# %%
# import streamlit as st
import pandas as pd

data = pd.read_csv('Data/data5.6_1.csv')
data2 = pd.read_csv('Data/data5.6_2.csv')
# st.subheader('Bảng dữ liệu data5.6_1.csv')
# st.dataframe(data)
print(data)
# Out:
#      gender  race/ethnicity parental level of education         lunch  \
# 0    female             3.0                some college      standard
# 1      male             4.0          associate's degree      standard
# 2    female             2.0                some college  free/reduced
# 3      male             0.0                some college           NaN
# 4    female             4.0          associate's degree      standard
# ..      ...             ...                         ...           ...
# 995    male             1.0                         NaN      standard
# 996    male             0.0                         NaN      standard
# 997  female             0.0                 high school      standard
# 998    male             1.0                 high school      standard
# 999    male             4.0                 high school      standard
#
#     test preparation course  math score
# 0                 completed        59.0
# 1                      none        96.0
# 2                      none        57.0
# 3                      none         NaN
# 4                      none        83.0
# ..                      ...         ...
# 995                    none        77.0
# 996                    none        80.0
# 997               completed        67.0
# 998                    none        80.0
# 999                    none        58.0
#
# [1000 rows x 6 columns]

# %%
print(data.dtypes)
# Out:
# gender                          object
# race/ethnicity                 float64
# parental level of education     object
# lunch                           object
# test preparation course         object
# math score                     float64
# dtype: object
